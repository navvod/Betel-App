# %%
# 1. INITIAL SETUP & LIBRARIES
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import zipfile
import datetime
import json
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries and VGG16 modules imported successfully!")
# Out:
# Mounted at /content/drive
# ✅ Libraries and VGG16 modules imported successfully!

# %%
# 2. DATASET EXTRACTION
dataset_zip_path = '/content/drive/MyDrive/dataset.zip'
extract_folder = '/content/betel_dataset'

if not os.path.exists(dataset_zip_path):
    print(f"❌ Dataset not found at: {dataset_zip_path}")
else:
    if os.path.exists(extract_folder):
        shutil.rmtree(extract_folder)
    os.makedirs(extract_folder, exist_ok=True)
    print("📦 Extracting dataset...")
    with zipfile.ZipFile(dataset_zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print("✅ Dataset extracted successfully!")
# Out:
# 📦 Extracting dataset...
# ✅ Dataset extracted successfully!

# %%
# 3. DIRECTORY SPLITTING (70/15/15)
base_path = '/content/betel_dataset'
source_data_path = os.path.join(base_path, 'dataset')
processed_data_root = os.path.join(base_path, 'commercial_classification')
os.makedirs(processed_data_root, exist_ok=True)

train_dir = os.path.join(processed_data_root, 'train')
val_dir = os.path.join(processed_data_root, 'val')
test_dir = os.path.join(processed_data_root, 'test')

# Logic to create splits if they don't exist
if not os.path.exists(train_dir):
    import random
    for split in ['train', 'val', 'test']:
        for cls in os.listdir(source_data_path):
            os.makedirs(os.path.join(processed_data_root, split, cls), exist_ok=True)

    for cls in os.listdir(source_data_path):
        cls_path = os.path.join(source_data_path, cls)
        if os.path.isdir(cls_path):
            images = [f for f in os.listdir(cls_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
            random.shuffle(images)
            n = len(images)
            train_idx, val_idx = int(n*0.7), int(n*0.85)

            for i, img in enumerate(images):
                src = os.path.join(cls_path, img)
                if i < train_idx: dst = os.path.join(train_dir, cls, img)
                elif i < val_idx: dst = os.path.join(val_dir, cls, img)
                else: dst = os.path.join(test_dir, cls, img)
                shutil.copy(src, dst)
    print("✅ Training, Validation, and Test splits created!")
# Out:
# ✅ Training, Validation, and Test splits created!

# %%
# 4. VGG16 DATA GENERATORS (With Heavy Augmentation)
# Note: VGG16 preprocess_input handles mean subtraction; we do NOT use rescale=1./255.
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    brightness_range=[0.7, 1.3],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True)

val_generator = val_test_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)

test_generator = val_test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)

num_classes = len(train_generator.class_indices)
# Out:
# Found 1131 images belonging to 4 classes.
# Found 242 images belonging to 4 classes.
# Found 245 images belonging to 4 classes.

# %%
# 5. BUILDING THE MODEL (FIXED: Added layers before summary)
print("\n🏗️ Building VGG16 Model...")
# Load the base
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_base.trainable = False # Freeze base initially

# Create the Sequential model and ADD layers
model = models.Sequential()
model.add(vgg_base)                 # Add base model first
model.add(layers.Flatten())         # Convert 3D features to 1D
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))      # Regularization to prevent overfitting
model.add(layers.Dense(num_classes, activation='softmax'))

# Now summary will show all parameters
model.summary()
# Out:
# 🏗️ Building VGG16 Model...
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     6,422,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,138,500 (80.64 MB)
#  Trainable params: 6,423,812 (24.50 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Use a low learning rate for Phase 1 to protect the pre-trained base
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

save_dir = '/content/vgg16_checkpoints'
os.makedirs(save_dir, exist_ok=True)
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# Properly formatted callback list to prevent syntax errors
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(save_dir, f'vgg16_best_{timestamp}.h5'),
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("✅ Callbacks and compilation configured successfully!")
# Out:
# ✅ Callbacks and compilation configured successfully!

# %%
print("\n🚀 TRAINING PHASE 1: Feature Extraction (Base Frozen)...")
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=30,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)
# Out:
# 🚀 TRAINING PHASE 1: Feature Extraction (Base Frozen)...
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8465 - loss: 0.4253
# Epoch 1: val_accuracy improved from -inf to 0.84821, saving model to /content/vgg16_checkpoints/vgg16_best_20260102_163841.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - accuracy: 0.8466 - loss: 0.4265 - val_accuracy: 0.8482 - val_loss: 0.5746
# Epoch 2/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8125 - loss: 0.4861
# Epoch 2: val_accuracy did not improve from 0.84821
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.8125 - loss: 0.4861 - val_accuracy: 0.8438 - val_loss: 0.5803
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8548 - loss: 0.4613
# Epoch 3: val_accuracy improved from 0.84821 to 0.87054, saving model to /content/vgg16_checkpoints/vgg16_best_20260102_163841.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step - accuracy: 0.8549 - loss: 0.4604 - val_accuracy: 0.8705 - val_loss: 0.4913
# Epoch 4/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.3821
# Epoch 4: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 384ms/step - accuracy: 0.8750 - loss: 0.3821 - val_accuracy: 0.8661 - val_loss: 0.4947
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8536 - loss: 0.4634
# Epoch 5: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.8535 - loss: 0.4630 - val_accuracy: 0.8036 - val_loss: 0.7998
# Epoch 6/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7188 - loss: 0.8958
# Epoch 6: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.7188 - loss: 0.8958 - val_accuracy: 0.8214 - val_loss: 0.7709
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8490 - loss: 0.4650
# Epoch 7: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.8491 - loss: 0.4645 - val_accuracy: 0.8393 - val_loss: 0.7047
# Epoch 8/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.4885
# Epoch 8: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 438ms/step - accuracy: 0.8750 - loss: 0.4885 - val_accuracy: 0.8393 - val_loss: 0.6741
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8568 - loss: 0.4024
# Epoch 9: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step - accuracy: 0.8570 - loss: 0.4021 - val_accuracy: 0.8482 - val_loss: 0.4599
# Epoch 10/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.3179
# Epoch 10: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 429ms/step - accuracy: 0.9375 - loss: 0.3179 - val_accuracy: 0.8482 - val_loss: 0.4563
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8664 - loss: 0.3892
# Epoch 11: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8663 - loss: 0.3894 - val_accuracy: 0.8616 - val_loss: 0.3627
# Epoch 12/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9688 - loss: 0.1125
# Epoch 12: val_accuracy did not improve from 0.87054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 438ms/step - accuracy: 0.9688 - loss: 0.1125 - val_accuracy: 0.8616 - val_loss: 0.3695
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8773 - loss: 0.3180
# Epoch 13: val_accuracy improved from 0.87054 to 0.88393, saving model to /content/vgg16_checkpoints/vgg16_best_20260102_163841.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step - accuracy: 0.8770 - loss: 0.3191 - val_accuracy: 0.8839 - val_loss: 0.3857
# Epoch 14/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8438 - loss: 0.3808
# Epoch 14: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 443ms/step - accuracy: 0.8438 - loss: 0.3808 - val_accuracy: 0.8839 - val_loss: 0.3960
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8819 - loss: 0.3495
# Epoch 15: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.8816 - loss: 0.3498 - val_accuracy: 0.8705 - val_loss: 0.4626
# Epoch 16/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8750 - loss: 0.1412
# Epoch 16: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - accuracy: 0.8750 - loss: 0.1412 - val_accuracy: 0.8616 - val_loss: 0.4765
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8738 - loss: 0.3705
# Epoch 17: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.8734 - loss: 0.3717 - val_accuracy: 0.8482 - val_loss: 0.5001
# Epoch 18/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.1834
# Epoch 18: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 467ms/step - accuracy: 0.9375 - loss: 0.1834 - val_accuracy: 0.8527 - val_loss: 0.5036
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8638 - loss: 0.4035
# Epoch 19: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.8638 - loss: 0.4039 - val_accuracy: 0.8571 - val_loss: 0.4317
# Epoch 20/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.3874
# Epoch 20: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 469ms/step - accuracy: 0.8750 - loss: 0.3874 - val_accuracy: 0.8571 - val_loss: 0.4371
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8382 - loss: 0.4178
# Epoch 21: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8391 - loss: 0.4156 - val_accuracy: 0.8616 - val_loss: 0.4000
# Epoch 22/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7812 - loss: 0.4390
# Epoch 22: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 425ms/step - accuracy: 0.7812 - loss: 0.4390 - val_accuracy: 0.8571 - val_loss: 0.4147
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8652 - loss: 0.3746
# Epoch 23: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 96s 3s/step - accuracy: 0.8653 - loss: 0.3742 - val_accuracy: 0.8571 - val_loss: 0.5393
# Epoch 24/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9688 - loss: 0.1298
# Epoch 24: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 447ms/step - accuracy: 0.9688 - loss: 0.1298 - val_accuracy: 0.8571 - val_loss: 0.5341
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8944 - loss: 0.3232
# Epoch 25: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 96s 3s/step - accuracy: 0.8943 - loss: 0.3229 - val_accuracy: 0.8616 - val_loss: 0.4610
# Epoch 26/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7812 - loss: 0.6559
# Epoch 26: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 438ms/step - accuracy: 0.7812 - loss: 0.6559 - val_accuracy: 0.8616 - val_loss: 0.4583
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8654 - loss: 0.3450
# Epoch 27: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8659 - loss: 0.3441 - val_accuracy: 0.8750 - val_loss: 0.3862
# Epoch 28/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8125 - loss: 0.3175
# Epoch 28: val_accuracy did not improve from 0.88393
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 447ms/step - accuracy: 0.8125 - loss: 0.3175 - val_accuracy: 0.8750 - val_loss: 0.3761
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8663 - loss: 0.3483
# Epoch 29: val_accuracy improved from 0.88393 to 0.89732, saving model to /content/vgg16_checkpoints/vgg16_best_20260102_163841.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.8663 - loss: 0.3485 - val_accuracy: 0.8973 - val_loss: 0.3426
# Epoch 30/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8438 - loss: 0.3215
# Epoch 30: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 455ms/step - accuracy: 0.8438 - loss: 0.3215 - val_accuracy: 0.8929 - val_loss: 0.3427

# %%
print("\n🚀 TRAINING PHASE 1: Feature Extraction (Base Frozen)...")
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=30,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)
# Out:
# 🚀 TRAINING PHASE 1: Feature Extraction (Base Frozen)...
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8778 - loss: 0.3281
# Epoch 1: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.8779 - loss: 0.3284 - val_accuracy: 0.8795 - val_loss: 0.3624
# Epoch 2/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8438 - loss: 0.5047
# Epoch 2: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 442ms/step - accuracy: 0.8438 - loss: 0.5047 - val_accuracy: 0.8795 - val_loss: 0.3669
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8898 - loss: 0.2857
# Epoch 3: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.8901 - loss: 0.2857 - val_accuracy: 0.8571 - val_loss: 0.4103
# Epoch 4/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.1768
# Epoch 4: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 447ms/step - accuracy: 0.9375 - loss: 0.1768 - val_accuracy: 0.8571 - val_loss: 0.4056
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8932 - loss: 0.3216
# Epoch 5: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8929 - loss: 0.3216 - val_accuracy: 0.8750 - val_loss: 0.3717
# Epoch 6/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8750 - loss: 0.4561
# Epoch 6: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 440ms/step - accuracy: 0.8750 - loss: 0.4561 - val_accuracy: 0.8795 - val_loss: 0.3676
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8886 - loss: 0.2760
# Epoch 7: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 99s 3s/step - accuracy: 0.8886 - loss: 0.2762 - val_accuracy: 0.8929 - val_loss: 0.3264
# Epoch 8/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9375 - loss: 0.3593
# Epoch 8: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 449ms/step - accuracy: 0.9375 - loss: 0.3593 - val_accuracy: 0.8973 - val_loss: 0.3317
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8897 - loss: 0.3308
# Epoch 9: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8895 - loss: 0.3303 - val_accuracy: 0.8750 - val_loss: 0.3778
# Epoch 10/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9062 - loss: 0.3210
# Epoch 10: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 451ms/step - accuracy: 0.9062 - loss: 0.3210 - val_accuracy: 0.8750 - val_loss: 0.3784
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8948 - loss: 0.3079
# Epoch 11: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.8945 - loss: 0.3090 - val_accuracy: 0.8750 - val_loss: 0.3776
# Epoch 12/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.3027
# Epoch 12: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 449ms/step - accuracy: 0.8750 - loss: 0.3027 - val_accuracy: 0.8750 - val_loss: 0.3779
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9017 - loss: 0.2932
# Epoch 13: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.9014 - loss: 0.2935 - val_accuracy: 0.8929 - val_loss: 0.3245
# Epoch 14/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9688 - loss: 0.1267
# Epoch 14: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 444ms/step - accuracy: 0.9688 - loss: 0.1267 - val_accuracy: 0.8929 - val_loss: 0.3297
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8772 - loss: 0.3068
# Epoch 15: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.8773 - loss: 0.3065 - val_accuracy: 0.8527 - val_loss: 0.4488
# Epoch 16/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.1755
# Epoch 16: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 445ms/step - accuracy: 0.9375 - loss: 0.1755 - val_accuracy: 0.8527 - val_loss: 0.4467
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8917 - loss: 0.2893
# Epoch 17: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 101s 3s/step - accuracy: 0.8918 - loss: 0.2897 - val_accuracy: 0.8571 - val_loss: 0.3785
# Epoch 18/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9375 - loss: 0.1240
# Epoch 18: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 462ms/step - accuracy: 0.9375 - loss: 0.1240 - val_accuracy: 0.8571 - val_loss: 0.3832
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8709 - loss: 0.3400
# Epoch 19: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.8711 - loss: 0.3400 - val_accuracy: 0.8661 - val_loss: 0.3727
# Epoch 20/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9688 - loss: 0.0951
# Epoch 20: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 446ms/step - accuracy: 0.9688 - loss: 0.0951 - val_accuracy: 0.8661 - val_loss: 0.3701
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8730 - loss: 0.3116
# Epoch 21: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8734 - loss: 0.3109 - val_accuracy: 0.8616 - val_loss: 0.4499
# Epoch 22/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7812 - loss: 0.4063
# Epoch 22: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 442ms/step - accuracy: 0.7812 - loss: 0.4063 - val_accuracy: 0.8616 - val_loss: 0.4671
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8764 - loss: 0.3502
# Epoch 23: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 99s 3s/step - accuracy: 0.8763 - loss: 0.3512 - val_accuracy: 0.8661 - val_loss: 0.4739
# Epoch 24/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.2486
# Epoch 24: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 451ms/step - accuracy: 0.9375 - loss: 0.2486 - val_accuracy: 0.8661 - val_loss: 0.4705
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8807 - loss: 0.2759
# Epoch 25: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step - accuracy: 0.8809 - loss: 0.2762 - val_accuracy: 0.8705 - val_loss: 0.4547
# Epoch 26/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0647
# Epoch 26: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 434ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.8705 - val_loss: 0.4566
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9010 - loss: 0.2590
# Epoch 27: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.9009 - loss: 0.2593 - val_accuracy: 0.8482 - val_loss: 0.5061
# Epoch 28/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8438 - loss: 0.5190
# Epoch 28: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 453ms/step - accuracy: 0.8438 - loss: 0.5190 - val_accuracy: 0.8438 - val_loss: 0.5274
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8852 - loss: 0.2935
# Epoch 29: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.8853 - loss: 0.2936 - val_accuracy: 0.8750 - val_loss: 0.4269
# Epoch 30/30
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9375 - loss: 0.2856
# Epoch 30: val_accuracy did not improve from 0.89732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - accuracy: 0.9375 - loss: 0.2856 - val_accuracy: 0.8750 - val_loss: 0.4271

# %%
print("\n🎯 Final Test Set Performance Evaluation:")
# Load the best weights saved by the checkpoint before evaluating
model.load_weights(os.path.join(save_dir, f'vgg16_best_{timestamp}.h5'))

test_loss, test_acc = model.evaluate(test_generator)
print(f"\n✅ FINAL TEST ACCURACY: {test_acc*100:.2f}%")
print(f"✅ FINAL TEST LOSS: {test_loss:.4f}")
# Out:
# 🎯 Final Test Set Performance Evaluation:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9260 - loss: 0.1690
#
# ✅ FINAL TEST ACCURACY: 86.53%
# ✅ FINAL TEST LOSS: 0.3396
