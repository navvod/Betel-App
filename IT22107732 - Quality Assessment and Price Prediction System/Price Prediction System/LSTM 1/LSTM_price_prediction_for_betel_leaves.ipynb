# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# %%
# Step 2: Load and SAFELY Clean the Dataset

df = pd.read_csv('BetelPrice.csv')

# Convert Date
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# Sort by Date
df = df.sort_values('Date').reset_index(drop=True)

# --- SAFE CLEANING: Only drop known garbage columns ---
print("Original columns:", df.columns.tolist())

# Explicitly drop only the unwanted columns by name
garbage_columns = ['Unnamed: 6', ' ']  # From your output
df = df.drop(columns=[col for col in garbage_columns if col in df.columns])

print("Columns after safe cleaning:", df.columns.tolist())

# Now verify expected columns are present
expected_cols = ['Date', 'District', 'Market Type', 'Commercial Type', 'Quality Grade', 'Price']
missing = [col for col in expected_cols if col not in df.columns]
if missing:
    print("WARNING: Missing expected columns:", missing)
else:
    print("All expected columns present!")

# Basic price cleaning
df = df.dropna(subset=['Price'])
df = df[df['Price'] > 0].reset_index(drop=True)

print("Final rows:", len(df))
print("Price range:", df['Price'].min(), "to", df['Price'].max())
# Out:
# Original columns: ['Date', 'District', 'Market Type', 'Commercial Type', 'Quality Grade', 'Price', 'Unnamed: 6', ' ']
# Columns after safe cleaning: ['Date', 'District', 'Market Type', 'Commercial Type', 'Quality Grade', 'Price']
# All expected columns present!
# Final rows: 9429
# Price range: 20 to 30000

# %%
categorical_cols = ['District', 'Market Type', 'Commercial Type', 'Quality Grade']

# Quick check of unique values
for col in categorical_cols:
    print(f"{col}: {df[col].unique().tolist()}")

# One-hot encode
# Use drop_first=True (recommended - avoids redundant columns)
df_encoded = pd.get_dummies(df, columns=categorical_cols, dtype=float, drop_first=True)

# Or if you prefer all columns: drop_first=False

encoded_cols = [col for col in df_encoded.columns if col not in ['Date', 'Price']]
print("\nEncoded columns count:", len(encoded_cols))
print("Encoded columns:", encoded_cols)
print("Total features (Price + encoded):", len(['Price'] + encoded_cols))

# Prepare data array
features = ['Price'] + encoded_cols
data = df_encoded[features].values.astype(np.float32)
dates = df_encoded['Date'].values
# Out:
# District: ['Kurunegala', 'Gampaha']
# Market Type: ['Export', 'Local']
# Commercial Type: ['Peedunu', 'Keti', 'Kanda', 'Korikan']
# Quality Grade: ['Premium', 'Standard']
#
# Encoded columns count: 6
# Encoded columns: ['District_Kurunegala', 'Market Type_Local', 'Commercial Type_Keti', 'Commercial Type_Korikan', 'Commercial Type_Peedunu', 'Quality Grade_Standard']
# Total features (Price + encoded): 7

# %%
# Log transform Price to handle wide range (20 to 30000)
data_log = data.copy()
data_log[:, 0] = np.log(data[:, 0])  # Natural log, prices > 0 → safe

# Scale the log-transformed Price to [0, 1]
scaler_price = MinMaxScaler(feature_range=(0, 1))
data_scaled = data_log.copy()

data_scaled[:, 0] = scaler_price.fit_transform(data_log[:, [0]]).flatten()

# Safety checks
print("Log+Scaled Price min/max:", data_scaled[:, 0].min(), data_scaled[:, 0].max())
print("Any NaN in data_scaled:", np.isnan(data_scaled).any())
print("Any Inf in data_scaled:", np.isinf(data_scaled).any())

# Inverse transform function (for predictions)
def inverse_price(pred_scaled):
    if pred_scaled.ndim == 1:
        pred_scaled = pred_scaled.reshape(-1, 1)
    pred_log = scaler_price.inverse_transform(pred_scaled)
    return np.exp(pred_log).flatten()  # Back to original price scale
# Out:
# Log+Scaled Price min/max: 0.0 1.0
# Any NaN in data_scaled: False
# Any Inf in data_scaled: False

# %%
def create_multivariate_sequences(data, time_steps=60):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps)])
        y.append(data[i + time_steps, 0])  # Predict next log-scaled price
    return np.array(X), np.array(y)

time_steps = 60
X, y = create_multivariate_sequences(data_scaled, time_steps)

print("X shape:", X.shape)  # Should be (9369, 60, 7)
print("y shape:", y.shape)
print("Any NaN in X/y:", np.isnan(X).any() or np.isnan(y).any())
# Out:
# X shape: (9369, 60, 7)
# y shape: (9369,)
# Any NaN in X/y: False

# %%
split_ratio = 0.8
split_idx = int(len(X) * split_ratio)

X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

# For plotting later
test_dates = dates[split_idx + time_steps:]

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 7495
# Testing samples: 1874

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

model = Sequential()
model.add(LSTM(units=64, return_sequences=True, input_shape=(time_steps, 7)))
model.add(Dropout(0.3))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1))  # Predict next price (log-scaled)

# Stable optimizer: low LR + gradient clipping
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005, clipnorm=1.0),
    loss='mse'
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 60, 64)         │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,569 (209.25 KB)
#  Trainable params: 53,569 (209.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=30,
    restore_best_weights=True,
    verbose=1
)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Training Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0904 - val_loss: 0.0263
# Epoch 2/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0218 - val_loss: 0.0236
# Epoch 3/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0195 - val_loss: 0.0249
# Epoch 4/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0194 - val_loss: 0.0274
# Epoch 5/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0189 - val_loss: 0.0240
# Epoch 6/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0184 - val_loss: 0.0231
# Epoch 7/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0186 - val_loss: 0.0242
# Epoch 8/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0181 - val_loss: 0.0227
# Epoch 9/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0176 - val_loss: 0.0228
# Epoch 10/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0181 - val_loss: 0.0222
# Epoch 11/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0177 - val_loss: 0.0217
# Epoch 12/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0168 - val_loss: 0.0216
# Epoch 13/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0170 - val_loss: 0.0218
# Epoch 14/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0164 - val_loss: 0.0210
# Epoch 15/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0161 - val_loss: 0.0207
# Epoch 16/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0148 - val_loss: 0.0210
# Epoch 17/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0153 - val_loss: 0.0203
# Epoch 18/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0158 - val_loss: 0.0194
# Epoch 19/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0145 - val_loss: 0.0189
# Epoch 20/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0147 - val_loss: 0.0190
# Epoch 21/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0146 - val_loss: 0.0177
# Epoch 22/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0136 - val_loss: 0.0179
# Epoch 23/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0133 - val_loss: 0.0174
# Epoch 24/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0132 - val_loss: 0.0168
# Epoch 25/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0128 - val_loss: 0.0163
# Epoch 26/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0126 - val_loss: 0.0168
# Epoch 27/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0122 - val_loss: 0.0158
# Epoch 28/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0120 - val_loss: 0.0153
# Epoch 29/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0120 - val_loss: 0.0143
# Epoch 30/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0113 - val_loss: 0.0144
# Epoch 31/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0118 - val_loss: 0.0140
# Epoch 32/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0112 - val_loss: 0.0141
# Epoch 33/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0107 - val_loss: 0.0132
# Epoch 34/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0103 - val_loss: 0.0140
# Epoch 35/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0105 - val_loss: 0.0125
# Epoch 36/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0104 - val_loss: 0.0137
# Epoch 37/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0100 - val_loss: 0.0125
# Epoch 38/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0104 - val_loss: 0.0128
# Epoch 39/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0101 - val_loss: 0.0119
# Epoch 40/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0102 - val_loss: 0.0106
# Epoch 41/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0095 - val_loss: 0.0112
# Epoch 42/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0095 - val_loss: 0.0108
# Epoch 43/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - val_loss: 0.0108
# Epoch 44/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 45/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - val_loss: 0.0121
# Epoch 46/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 47/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0091 - val_loss: 0.0104
# Epoch 48/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0087 - val_loss: 0.0113
# Epoch 49/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0087 - val_loss: 0.0097
# Epoch 50/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0081 - val_loss: 0.0097
# Epoch 51/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0084 - val_loss: 0.0101
# Epoch 52/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0082 - val_loss: 0.0096
# Epoch 53/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 54/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 55/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0081 - val_loss: 0.0098
# Epoch 56/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 57/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0078 - val_loss: 0.0093
# Epoch 58/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 59/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 60/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0078 - val_loss: 0.0085
# Epoch 61/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 62/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 63/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0077 - val_loss: 0.0083
# Epoch 64/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0078 - val_loss: 0.0098
# Epoch 65/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 66/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0074 - val_loss: 0.0087
# Epoch 67/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0073 - val_loss: 0.0080
# Epoch 68/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 69/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 70/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 71/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 72/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 73/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 74/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0069 - val_loss: 0.0087
# Epoch 75/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0066 - val_loss: 0.0078
# Epoch 76/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0067 - val_loss: 0.0077
# Epoch 77/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0070 - val_loss: 0.0079
# Epoch 78/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0065 - val_loss: 0.0077
# Epoch 79/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 80/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0070 - val_loss: 0.0076
# Epoch 81/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0068 - val_loss: 0.0077
# Epoch 82/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 83/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0067 - val_loss: 0.0075
# Epoch 84/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - val_loss: 0.0076
# Epoch 85/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 86/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 87/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 88/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 89/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0061 - val_loss: 0.0073
# Epoch 90/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - val_loss: 0.0078
# Epoch 91/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0063 - val_loss: 0.0076
# Epoch 92/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 93/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 94/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0058 - val_loss: 0.0074
# Epoch 95/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 96/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0056 - val_loss: 0.0073
# Epoch 97/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0056 - val_loss: 0.0075
# Epoch 98/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0058 - val_loss: 0.0069
# Epoch 99/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0056 - val_loss: 0.0078
# Epoch 100/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 101/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0055 - val_loss: 0.0068
# Epoch 102/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0055 - val_loss: 0.0072
# Epoch 103/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 104/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 105/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 106/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0055 - val_loss: 0.0073
# Epoch 107/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0054 - val_loss: 0.0066
# Epoch 108/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0055 - val_loss: 0.0068
# Epoch 109/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 110/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 111/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0054 - val_loss: 0.0066
# Epoch 112/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0051 - val_loss: 0.0070
# Epoch 113/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0055 - val_loss: 0.0066
# Epoch 114/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0051 - val_loss: 0.0068
# Epoch 115/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 116/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0046 - val_loss: 0.0071
# Epoch 117/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 118/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 119/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0050 - val_loss: 0.0063
# Epoch 120/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0049 - val_loss: 0.0066
# Epoch 121/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 122/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0048 - val_loss: 0.0062
# Epoch 123/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 124/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0047 - val_loss: 0.0065
# Epoch 125/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0048 - val_loss: 0.0063
# Epoch 126/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0044 - val_loss: 0.0063
# Epoch 127/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0051 - val_loss: 0.0069
# Epoch 128/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 129/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 130/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 131/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0047 - val_loss: 0.0062
# Epoch 132/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 133/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 134/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 135/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0047 - val_loss: 0.0065
# Epoch 136/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0048 - val_loss: 0.0062
# Epoch 137/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0059
# Epoch 138/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0047 - val_loss: 0.0060
# Epoch 139/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 140/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 141/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 142/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 143/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 144/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0048 - val_loss: 0.0062
# Epoch 145/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0044 - val_loss: 0.0062
# Epoch 146/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 147/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 148/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0042 - val_loss: 0.0064
# Epoch 149/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 150/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 151/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 152/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0042 - val_loss: 0.0056
# Epoch 153/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 154/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 155/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0042 - val_loss: 0.0057
# Epoch 156/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 157/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 158/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 159/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0038 - val_loss: 0.0068
# Epoch 160/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 161/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0037 - val_loss: 0.0059
# Epoch 162/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 163/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 164/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 165/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0039 - val_loss: 0.0060
# Epoch 166/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 167/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 168/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 169/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 170/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 171/200
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0036 - val_loss: 0.0059
# Epoch 171: early stopping
# Restoring model weights from the end of the best epoch: 141.

# %%
y_pred_scaled = model.predict(X_test)
y_pred = inverse_price(y_pred_scaled)
y_true = inverse_price(y_test)

from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

print(f"Test RMSE: {rmse:.2f}")
print(f"Test MAE:  {mae:.2f}")
print(f"Test MAPE: {mape:.2f}%")
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test RMSE: 3071.77
# Test MAE:  1957.15
# Test MAPE: 48.54%

# %%
plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_true, label='Actual Price', alpha=0.8)
plt.plot(test_dates, y_pred, label='Predicted Price', alpha=0.8)
plt.title('Betel Leaf Price Prediction - Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
model.save('betel_price_lstm_model.h5')
joblib.dump(scaler_price, 'betel_price_log_scaler.pkl')
print("Model and scaler saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and scaler saved successfully!
